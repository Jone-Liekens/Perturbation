# %%
from sympy import symbols, Function, diff, expand, collect, pprint, latex, \
    sin, cos, integrate, O, simplify, pi, init_session, init_printing

import matplotlib

init_printing()

# %%
# for interactive session
# init_session()

# for notebooks:
# init_printing(use_latex='mathjax')
# import IPython.display as disp



x = symbols('x')
t = symbols('t')
eps = symbols("self.epsilon")


u1_r = Function('u1r_x')(x)
u1_c = Function('u1c_x')(x)
u1_s = Function('u1s_x')(x)

u0_c = Function('u0c_x')(x)
u0_s = Function('u0s_x')(x)


u1 = u1_r + u1_c * cos(2*t) + u1_s * sin(2*t)
u0 = u0_c * cos(t) + u0_s * sin(t)

# ignore terms of order eps**2
# u_comp = expand(diff((u0 + eps * u1)**5, x)) + O(eps**2)
u_comp = expand(diff((u0 + eps * u1)**5, x)) + O(eps**2)


q = integrate(u_comp, (t, 0, 2*pi))


# q = diff(q, x)
q = simplify(q)
q = collect(q, eps)
# q = collect(q, u0_c)

# pprint(q)

l = str(q)
# print(len(l))
l = l.replace('Derivative(u1r_x(x), x)', 'u1r_x_dx')
l = l.replace('Derivative(u1c_x(x), x)', 'u1c_x_dx')
l = l.replace('Derivative(u1s_x(x), x)', 'u1s_x_dx')
l = l.replace('Derivative(u0c_x(x), x)', 'u0c_x_dx')
l = l.replace('Derivative(u0s_x(x), x)', 'u0s_x_dx')
l = l.replace('(x)', '')
l = l.replace(' + O(self.epsilon**2)', '')
# print(len(l))
print(l)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 28
#      24 u0 = u0_c * cos(t) + u0_s * sin(t)
#      26 # ignore terms of order eps**2
#      27 # u_comp = expand(diff((u0 + eps * u1)**5, x)) + O(eps**2)
# ---> 28 u_comp = expand(diff((u0 + eps * u1)**5), x) + O(eps**2)
#      31 q = integrate(u_comp, (t, 0, 2*pi))
#      34 # q = diff(q, x)
#
# File c:\Users\jolieken\Code\Perturbation\venv\Lib\site-packages\sympy\core\function.py:2511, in diff(f, *symbols, **kwargs)
#    2447 """
#    2448 Differentiate f with respect to symbols.
#    2449
#    (...)   2508
#    2509 """
#    2510 if hasattr(f, 'diff'):
# -> 2511     return f.diff(*symbols, **kwargs)
#    2512 kwargs.setdefault('evaluate', True)
#    2513 return _derivative_dispatch(f, *symbols, **kwargs)
#
# File c:\Users\jolieken\Code\Perturbation\venv\Lib\site-packages\sympy\core\expr.py:3606, in Expr.diff(self, *symbols, **assumptions)
#    3604 def diff(self, *symbols, **assumptions):
#    3605     assumptions.setdefault("evaluate", True)
# -> 3606     return _derivative_dispatch(self, *symbols, **assumptions)
#
# File c:\Users\jolieken\Code\Perturbation\venv\Lib\site-packages\sympy\core\function.py:1938, in _derivative_dispatch(expr, *variables, **kwargs)
#    1936     from sympy.tensor.array.array_derivatives import ArrayDerivative
#    1937     return ArrayDerivative(expr, *variables, **kwargs)
# -> 1938 return Derivative(expr, *variables, **kwargs)
#
# File c:\Users\jolieken\Code\Perturbation\venv\Lib\site-packages\sympy\core\function.py:1284, in Derivative.__new__(cls, expr, *variables, **kwargs)
#    1279             raise ValueError(filldedent('''
#    1280                 Since there are no variables in the expression,
#    1281                 the variable(s) of differentiation must be supplied
#    1282                 to differentiate %s''' % expr))
#    1283         else:
# -> 1284             raise ValueError(filldedent('''
#    1285                 Since there is more than one variable in the
#    1286                 expression, the variable(s) of differentiation
#    1287                 must be supplied to differentiate %s''' % expr))
#    1289 # Split the list of variables into a list of the variables we are diff
#    1290 # wrt, where each element of the list has the form (s, count) where
#    1291 # s is the entity to diff wrt and count is the order of the
#    1292 # derivative.
#    1293 variable_count = []
#
# ValueError:
# Since there is more than one variable in the expression, the
# variable(s) of differentiation must be supplied to differentiate
# (self.epsilon*(u1c_x(x)*cos(2*t) + u1r_x(x) + u1s_x(x)*sin(2*t)) +
# u0c_x(x)*cos(t) + u0s_x(x)*sin(t))**5
