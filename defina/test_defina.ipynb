# %%
# %load_ext autoreload
# %reload_ext autoreload
# %autoreload 2

import numpy as np
import matplotlib.pyplot as plt

from matplotlib import cm
from numpy.polynomial import chebyshev
from cycler import cycler

# %%
from pdswe import PDSWE

# %%
pdswe = PDSWE()
pdswe.H = 7.12
pdswe.A = 0.72
pdswe.L = 8e3
pdswe.r = 0.3

pdswe.tol = 1e-7


pdswe.a_r = 0.1
pdswe.dL = 0


factor = 0.9
factor = 1
h_fx = lambda x: factor*x
h_fx_dx = lambda x: factor
h_fx_dxx = lambda x: 0

pdswe.h_fx = h_fx
pdswe.h_fx_dx = h_fx_dx
pdswe.h_fx_dxx = h_fx_dxx


pdswe.set_derivative_vars()

pdswe.solve()

pdswe.visualize_components(0)
pdswe.visualize_amplitudes(0)
# Out:
#    Iteration    Max residual  Max BC residual  Total nodes    Nodes added
#        1          4.26e-05       8.80e-28         1000            108
#        2          1.75e-06       2.35e-27         1108            127
#        3          2.24e-07       2.08e-29         1235            54
#        4          9.83e-08       1.05e-30         1289             0
# Solved in 4 iterations, number of nodes 1289.
# Maximum relative residual: 9.83e-08
# Maximum boundary residual: 1.05e-30

# %%
fig, axs = plt.subplots(2, 6, figsize=(30, 10))
fig2, axs2 = plt.subplots(2, 6, figsize=(30, 10))

# for dL in [0, 0.05, 0.08, 0.1, 0.12, 0.14, 0.16, 0.18, 0.2, 0.22, 0.24, 0.26]:
# for dL in [0]:
# for dL in [0, 0.05, 0.08, 0.1, 0.12]:
# for dL in [0.2, 0.225, 0.25, 0.275, 0.3]:
# for dL in [0.2, 0.21, 0.22, 0.223, 0.225, 0.25, 0.26][::-1]:
# for dL in [0.2, 0.22, 0.24, 0.26, 0.27, 0.28, 0.29, 0.3][::-1]:
for dL in [0.26]:
    pdswe.dL = dL
    pdswe.set_derivative_vars()
    pdswe.solve()
    pdswe.visualize_amplitudes(0.7, axs=axs)
    pdswe.visualize_defina_vars(0.7, axs=axs2)
plt.show()
# Out:
#    Iteration    Max residual  Max BC residual  Total nodes    Nodes added
#        1          1.50e-02       8.49e-24         1000            123
#        2          1.27e-03       2.93e-28         1123            142
#        3          5.29e-04       2.86e-28         1265            139
#        4          8.14e-05       3.76e-30         1404            16
#        5          1.92e-05       1.06e-32         1420             3
#        6          9.93e-06       4.94e-34         1423             0
# Solved in 6 iterations, number of nodes 1423.
# Maximum relative residual: 9.93e-06
# Maximum boundary residual: 4.94e-34

# %%
fig, axs = plt.subplots(2, 6, figsize=(30, 10))
fig2, axs2 = plt.subplots(2, 6, figsize=(30, 10))


pdswe.dL = 0.2
for f in [0.8, 0.85, 0.9, 0.95, 1]:

    factor = f
    h_fx = lambda x: factor*x
    h_fx_dx = lambda x: factor
    h_fx_dxx = lambda x: 0

    pdswe.set_derivative_vars()
    pdswe.solve()
    pdswe.visualize_amplitudes(0.8, axs=axs)
    pdswe.visualize_defina_vars(0.8, axs=axs2)
plt.show()
# Out:
#    Iteration    Max residual  Max BC residual  Total nodes    Nodes added
#        1          5.24e-06       1.90e-28         1000            104
#        2          7.04e-07       2.56e-28         1104            139
#        3          9.91e-08       1.22e-29         1243             0
# Solved in 3 iterations, number of nodes 1243.
# Maximum relative residual: 9.91e-08
# Maximum boundary residual: 1.22e-29
#    Iteration    Max residual  Max BC residual  Total nodes    Nodes added
#        1          2.76e-04       5.87e-28         1000            129
#        2          1.19e-05       1.84e-27         1129            142
#        3          1.12e-06       7.43e-29         1271            110
#        4          1.43e-07       1.45e-30         1381            10
#        5          1.00e-07       3.82e-33         1391             0
# Solved in 5 iterations, number of nodes 1391.
# Maximum relative residual: 1.00e-07
# Maximum boundary residual: 3.82e-33
#    Iteration    Max residual  Max BC residual  Total nodes    Nodes added
#        1          4.89e-02       5.27e-28         1000            209
#        2          3.12e-03       4.79e-27         1209            270
#        3          1.52e-04       1.76e-29         1479            242
#        4          6.18e-06       2.12e-30         1721            104
#        5          7.98e-07       2.17e-31         1825            44
#        6          1.03e-07       8.79e-33         1869             1
#        7          1.00e-07       2.33e-34         1870             0
# Solved in 7 iterations, number of nodes 1870.
# Maximum relative residual: 1.00e-07
# Maximum boundary residual: 2.33e-34
#    Iteration    Max residual  Max BC residual  Total nodes    Nodes added
#        1          5.94e-02       2.32e-24         1000            321
#        2          1.85e-03       1.23e-32         1321            537
#        3          1.94e-04       8.30e-28         1858            697
#        4          2.01e-05       6.51e-26         2555            743
#        5          2.24e-06       1.88e-28         3298            248
#        6          2.53e-07       1.70e-32         3546            10
#        7          9.99e-08       3.68e-32         3556             0
# Solved in 7 iterations, number of nodes 3556.
# Maximum relative residual: 9.99e-08
# Maximum boundary residual: 3.68e-32
#    Iteration    Max residual  Max BC residual  Total nodes    Nodes added
#        1          1.46e-01       6.23e-33         1000            319
#        2          1.59e-03       1.62e-31         1319            538
#        3          8.00e-05       7.05e-27         1857            688
#        4          1.38e-05       2.30e-26         2545            729
#        5          2.62e-06       1.00e-28         3274            298
#        6          3.74e-07       1.86e-31         3572            10
#        7          9.99e-08       1.35e-33         3582             0
# Solved in 7 iterations, number of nodes 3582.
# Maximum relative residual: 9.99e-08
# Maximum boundary residual: 1.35e-33

# %%
fig, axs = plt.subplots(3, 6, figsize=(30, 15))
labels=[r"$\zeta^0_{c1}$", r"$\zeta^0_{s1}$", r"$u^0_{c1}$", r"$u^0_{s1}$", r"$\zeta^1_{r}$", r"$\zeta^1_{c2}$", r"$\zeta^1_{s2}$", r"$u^1_{r}$", r"$u^1_{c2}$", r"$u^1_{s2}$"]

# for dL in [0, 0.05, 0.08, 0.1, 0.12, 0.14, 0.16, 0.18, 0.2, 0.22, 0.24, 0.26]:
# for dL in [0]:
# for dL in [0, 0.05, 0.08, 0.1, 0.12]:
for dL in [0.2, 0.225, 0.25, 0.275, 0.3]:
    pdswe.dL = dL

    pdswe.set_derivative_vars()
    pdswe.solve()

    st = np.argmin(abs(pdswe.y.x - 1.05))


    for i in range(4):
        axs[0, i].set_title(labels[i])
        axs[0, i].plot([1, 1], [min(pdswe.y.y[i]), max(pdswe.y.y[i])], 'k')
        axs[0, i].plot(pdswe.y.x[st:], pdswe.y.y[i, st:])
        

    for i in range(6):
        axs[1, i].set_title(labels[4 + i])
        axs[1, i].plot([1, 1], [min(pdswe.y.y[4 + i]), max(pdswe.y.y[4 + i])], 'k')
        axs[1, i].plot(pdswe.y.x[st:], pdswe.y.y[4 + i, st:])

    dfvars = pdswe.defina_vars(pdswe.y.x, pdswe.y.y)
    for i in range(6):
        axs[2, i].plot(pdswe.y.x[st:], dfvars[i][st:])



    
    

plt.show()
# Out:
#    Iteration    Max residual  Max BC residual  Total nodes    Nodes added
#        1          1.46e-01       6.23e-33         1000            319
#        2          1.59e-03       1.62e-31         1319            538
#        3          8.00e-05       7.05e-27         1857            688
#        4          1.38e-05       2.30e-26         2545            729
#        5          2.62e-06       1.00e-28         3274            298
#        6          3.74e-07       1.86e-31         3572            10
#        7          9.99e-08       1.35e-33         3582             0
# Solved in 7 iterations, number of nodes 3582.
# Maximum relative residual: 9.99e-08
# Maximum boundary residual: 1.35e-33
#    Iteration    Max residual  Max BC residual  Total nodes    Nodes added
#        1          1.49e-02       3.10e-30         1000            316
#        2          1.10e-03       1.67e-29         1316            535
#        3          2.99e-04       4.47e-27         1851            685
#        4          1.50e-05       1.74e-26         2536            750
#        5          1.17e-06       7.42e-29         3286            320
#        6          2.66e-07       3.93e-32         3606            10
#        7          1.00e-07       5.51e-33         3616             0
# Solved in 7 iterations, number of nodes 3616.
# Maximum relative residual: 1.00e-07
# Maximum boundary residual: 5.51e-33
#    Iteration    Max residual  Max BC residual  Total nodes    Nodes added
#        1          7.09e+01       2.15e+04         1000           1998
#        2          4.63e+03       5.26e-23         2998            926
#        3          7.16e-04       1.69e-32         3924            655
#        4          9.91e-06       3.31e-25         4579            751
#        5          1.70e-06       1.46e-26         5330            336
#        6          6.31e-07       3.55e-28         5666            15
#        7          9.98e-08       3.14e-31         5681             0
# Solved in 7 iterations, number of nodes 5681.
# Maximum relative residual: 9.98e-08
# Maximum boundary residual: 3.14e-31
#    Iteration    Max residual  Max BC residual  Total nodes    Nodes added
#        1          2.54e+05       1.03e+07         1000           1998
#        2          7.95e+05       1.10e+21         2998           5994
#        3          3.32e+06       1.43e+34         8992          (17982)
# Number of nodes is exceeded after iteration 3.
# Maximum relative residual: 3.32e+06
# Maximum boundary residual: 1.43e+34
#        message: The maximum number of mesh nodes is exceeded.
#        success: False
#         status: 1
#              x: [ 0.000e+00  1.418e-04 ...  1.275e+00  1.275e+00]
#            sol: <scipy.interpolate._interpolate.PPoly object at 0x0000017EB37BE430>
#              p: None
#              y: [[ 2.337e+27  2.337e+27 ... -1.485e+31 -1.359e+31]
#                  [-5.866e+25 -5.869e+25 ...  9.375e+30  8.577e+30]
#                  ...
#                  [ 9.432e+39  9.430e+39 ...  1.096e+61  0.000e+00]
#                  [ 3.335e+39  3.330e+39 ... -1.113e+64  0.000e+00]]
#             yp: [[-3.554e+24 -3.553e+24 ... -2.155e+38 -2.167e+38]
#                  [-1.985e+26 -1.985e+26 ...  2.129e+38  2.137e+38]
#                  ...
#                  [ 1.122e+55  1.122e+55 ... -5.316e+66 -5.059e+66]
#                  [-7.788e+54 -7.792e+54 ...  2.323e+68 -7.633e+67]]
#  rms_residuals: [ 2.514e+00  2.514e+00 ...  1.903e+02  1.734e+01]
#          niter: 3
# ---------------------------------------------------------------------------
# SystemError                               Traceback (most recent call last)
# Cell In[6], line 11
#       8 pdswe.dL = dL
#      10 pdswe.set_derivative_vars()
# ---> 11 pdswe.solve()
#      13 st = np.argmin(abs(pdswe.y.x - 1.05))
#      16 for i in range(4):
#
# File c:\Users\jolieken\Code\Perturbation\pdswe.py:256, in PDSWE.solve(self)
#     254 if sol.status or self.debug:
#     255     print(sol)
# --> 256     raise SystemError
#
# SystemError:

# %% [markdown]
# # Just Leading Order

# %%
pdswe = PDSWE()
pdswe.H = 7.12
pdswe.A = 0.72
pdswe.L = 8e3
pdswe.r = 0.3

pdswe.tol = 1e-5


pdswe.a_r = 0.1
pdswe.dL = 0.15


pdswe.set_derivative_vars()

pdswe.solve_LO()


# fig, axs = plt.subplots(2, 4, figsize=(20, 10))

# for i in range(4):
#     axs[0, i].set_title(labels[i])
#     axs[0, i].plot(pdswe.y.x, pdswe.y.y[i])


# plt.show()


factor = 0.9
h_fx = lambda x: factor*x
h_fx_dx = lambda x: factor
h_fx_dxx = lambda x: 0

pdswe.h_fx = h_fx
pdswe.h_fx_dx = h_fx_dx
pdswe.h_fx_dxx = h_fx_dxx



fig, axs = plt.subplots(2, 6, figsize=(30, 10))
labels=[r"$\zeta^0_{c1}$", r"$\zeta^0_{s1}$", r"$u^0_{c1}$", r"$u^0_{s1}$", r"$\zeta^1_{r}$", r"$\zeta^1_{c2}$", r"$\zeta^1_{s2}$", r"$u^1_{r}$", r"$u^1_{c2}$", r"$u^1_{s2}$"]

for dL in [0, 0.05, 0.08, 0.1, 0.12, 0.14, 0.16, 0.18, 0.2, 0.22, 0.24, 0.26, 0.28][::-1]:
# for dL in [0]:
    pdswe.dL = dL

    pdswe.set_derivative_vars()
    pdswe.solve_LO()


    for i in range(4):
        axs[0, i].set_title(labels[i])
        axs[0, i].plot(pdswe.y.x, pdswe.y.y[i])




plt.show()
# Out:
#    Iteration    Max residual  Max BC residual  Total nodes    Nodes added
#        1          1.69e-03       0.00e+00         1000            72
#        2          1.30e-04       0.00e+00         1072            80
#        3          1.73e-05       0.00e+00         1152            25
#        4          9.86e-06       0.00e+00         1177             0
# Solved in 4 iterations, number of nodes 1177.
# Maximum relative residual: 9.86e-06
# Maximum boundary residual: 0.00e+00
#    Iteration    Max residual  Max BC residual  Total nodes    Nodes added
#        1          1.60e-03       2.54e-25         1000            70
#        2          2.40e-04       4.77e-32         1070            77
#        3          2.91e-05       3.72e-34         1147            28
#        4          9.99e-06       1.26e-35         1175             0
# Solved in 4 iterations, number of nodes 1175.
# Maximum relative residual: 9.99e-06
# Maximum boundary residual: 1.26e-35
#    Iteration    Max residual  Max BC residual  Total nodes    Nodes added
#        1          2.57e-03       0.00e+00         1000            64
#        2          1.33e-04       0.00e+00         1064            73
#        3          1.89e-05       0.00e+00         1137            26
#        4          9.91e-06       0.00e+00         1163             0
# Solved in 4 iterations, number of nodes 1163.
# Maximum relative residual: 9.91e-06
# Maximum boundary residual: 0.00e+00
#    Iteration    Max residual  Max BC residual  Total nodes    Nodes added
#        1          5.39e-03       1.52e-09         1000            38
#        2          4.26e-04       0.00e+00         1038            31
#        3          7.00e-05       0.00e+00         1069            14
#        4          1.05e-05       0.00e+00         1083             1
#        5          9.72e-06       0.00e+00         1084             0
# Solved in 5 iterations, number of nodes 1084.
# Maximum relative residual: 9.72e-06
# Maximum boundary residual: 0.00e+00
#    Iteration    Max residual  Max BC residual  Total nodes    Nodes added
#        1          1.99e-03       1.52e-09         1000            24
#        2          1.40e-04       0.00e+00         1024            10
#        3          2.29e-05       0.00e+00         1034             2
#        4          9.91e-06       0.00e+00         1036             0
# Solved in 4 iterations, number of nodes 1036.
# Maximum relative residual: 9.91e-06
# Maximum boundary residual: 0.00e+00
#    Iteration    Max residual  Max BC residual  Total nodes    Nodes added
#        1          6.11e-04       1.52e-09         1000            22
#        2          1.01e-04       0.00e+00         1022             8
#        3          1.52e-05       0.00e+00         1030             1
#        4          9.58e-06       0.00e+00         1031             0
# Solved in 4 iterations, number of nodes 1031.
# Maximum relative residual: 9.58e-06
# Maximum boundary residual: 0.00e+00
#    Iteration    Max residual  Max BC residual  Total nodes    Nodes added
#        1          1.48e-04       1.52e-09         1000            10
#        2          2.15e-05       0.00e+00         1010             3
#        3          9.50e-06       0.00e+00         1013             0
# Solved in 3 iterations, number of nodes 1013.
# Maximum relative residual: 9.50e-06
# Maximum boundary residual: 0.00e+00
#    Iteration    Max residual  Max BC residual  Total nodes    Nodes added
#        1          3.32e-05       1.52e-09         1000             5
#        2          9.88e-06       0.00e+00         1005             0
# Solved in 2 iterations, number of nodes 1005.
# Maximum relative residual: 9.88e-06
# Maximum boundary residual: 0.00e+00
#    Iteration    Max residual  Max BC residual  Total nodes    Nodes added
#        1          7.83e-06       1.52e-09         1000             0
# Solved in 1 iterations, number of nodes 1000.
# Maximum relative residual: 7.83e-06
# Maximum boundary residual: 1.52e-09
#    Iteration    Max residual  Max BC residual  Total nodes    Nodes added
#        1          2.26e-06       1.52e-09         1000             0
# Solved in 1 iterations, number of nodes 1000.
# Maximum relative residual: 2.26e-06
# Maximum boundary residual: 1.52e-09
#    Iteration    Max residual  Max BC residual  Total nodes    Nodes added
#        1          9.36e-07       1.52e-09         1000             0
# Solved in 1 iterations, number of nodes 1000.
# Maximum relative residual: 9.36e-07
# Maximum boundary residual: 1.52e-09
#    Iteration    Max residual  Max BC residual  Total nodes    Nodes added
#        1          5.15e-07       1.52e-09         1000             0
# Solved in 1 iterations, number of nodes 1000.
# Maximum relative residual: 5.15e-07
# Maximum boundary residual: 1.52e-09
#    Iteration    Max residual  Max BC residual  Total nodes    Nodes added
#        1          2.49e-07       1.52e-09         1000             0
# Solved in 1 iterations, number of nodes 1000.
# Maximum relative residual: 2.49e-07
# Maximum boundary residual: 1.52e-09
#    Iteration    Max residual  Max BC residual  Total nodes    Nodes added
#        1          7.82e-08       1.52e-09         1000             0
# Solved in 1 iterations, number of nodes 1000.
# Maximum relative residual: 7.82e-08
# Maximum boundary residual: 1.52e-09

# %%
pdswe = PDSWE()
pdswe.H = 7.12
pdswe.A = 0.72
pdswe.L = 8e3
pdswe.r = 0.3

pdswe.tol = 1e-5

pdswe.a_r = 0.1
pdswe.dL = 0.15

pdswe.set_derivative_vars()
pdswe.solve_LO()


factor = 0.9
h_fx = lambda x: factor*x
h_fx_dx = lambda x: factor
h_fx_dxx = lambda x: 0

pdswe.h_fx = h_fx
pdswe.h_fx_dx = h_fx_dx
pdswe.h_fx_dxx = h_fx_dxx



fig, axs = plt.subplots(2, 6, figsize=(30, 10))
labels=[r"$\zeta^0_{c1}$", r"$\zeta^0_{s1}$", r"$u^0_{c1}$", r"$u^0_{s1}$", r"$\zeta^1_{r}$", r"$\zeta^1_{c2}$", r"$\zeta^1_{s2}$", r"$u^1_{r}$", r"$u^1_{c2}$", r"$u^1_{s2}$"]

pdswe.dL = 0.26

pdswe.set_derivative_vars()
pdswe.solve_LO()


for i in range(4):
    axs[0, i].set_title(labels[i])
    axs[0, i].plot(pdswe.y.x, pdswe.y.y[i])




lala = pdswe.visualize_LO_effects()
for i in range(3):
    axs[1, i].plot(pdswe.y.x, lala[i])

from scipy.integrate import cumulative_trapezoid as cumtrapz

for i in range(3):
    axs[1, 3+i].plot(pdswe.y.x, cumtrapz(pdswe.y.x, lala[i], initial=0))


plt.show()
# Out:
#    Iteration    Max residual  Max BC residual  Total nodes    Nodes added
#        1          1.69e-03       0.00e+00         1000            72
#        2          1.30e-04       0.00e+00         1072            80
#        3          1.73e-05       0.00e+00         1152            25
#        4          9.86e-06       0.00e+00         1177             0
# Solved in 4 iterations, number of nodes 1177.
# Maximum relative residual: 9.86e-06
# Maximum boundary residual: 0.00e+00
#    Iteration    Max residual  Max BC residual  Total nodes    Nodes added
#        1          2.57e-03       0.00e+00         1000            64
#        2          1.33e-04       0.00e+00         1064            73
#        3          1.89e-05       0.00e+00         1137            26
#        4          9.91e-06       0.00e+00         1163             0
# Solved in 4 iterations, number of nodes 1163.
# Maximum relative residual: 9.91e-06
# Maximum boundary residual: 0.00e+00

# %%
pdswe.solve()


fig, axs = plt.subplots(2, 6, figsize=(30, 10))
dfvars = pdswe.visualize_defina_vars(axs=axs)
plt.show()



eta0_x, Y0_x, eta1c_x, eta1s_x, dz0c_x, dz0s_x, Y0_x_dx, eta0_x_dx = dfvars
x = pdswe.y.x
plt.plot(pdswe.y.x, eta0_x / Y0_x)
plt.show()
# Out:
#    Iteration    Max residual  Max BC residual  Total nodes    Nodes added
#        1          1.50e-02       8.49e-24         1000            123
#        2          1.27e-03       2.93e-28         1123            142
#        3          5.29e-04       2.86e-28         1265            139
#        4          8.14e-05       3.76e-30         1404            16
#        5          1.92e-05       1.06e-32         1420             3
#        6          9.93e-06       4.94e-34         1423             0
# Solved in 6 iterations, number of nodes 1423.
# Maximum relative residual: 9.93e-06
# Maximum boundary residual: 4.94e-34

# %%
A = Y0_x * eta0_x
B = 2 * Y0_x_dx * eta0_x - Y0_x * eta0_x_dx
C = np.gradient(Y0_x_dx, x) * eta0_x - Y0_x_dx * eta0_x_dx
D = - eta0_x**2 * pdswe.r / pdswe.kappa / Y0_x
E = - eta0_x**2 / pdswe.kappa

F = C + D + E

fig, axs = plt.subplots(2, 6, figsize=(30, 10))

axs[0, 0].plot(x, A)
axs[0, 1].plot(x, B)
axs[0, 2].plot(x, C)
axs[0, 3].plot(x, D)
axs[0, 4].plot(x, E)
axs[0, 5].plot(x, F)



# celerity
k = - 1j * B + np.sqrt(-B**2 + 4 * A * F + 0j) / (- 2 * A)
k2 = - 1j * B - np.sqrt(-B**2 + 4 * A * F + 0j) / (- 2 * A)



# axs[1, 0].plot(x, -B**2 + 4 * A * F)
axs[1, 0].plot(x, np.real(k))
axs[1, 1].plot(x, np.imag(k))
axs[1, 2].plot(x, np.real(k2))
axs[1, 3].plot(x, np.imag(k2))



plt.show()

# %%
print(pdswe.kappa)
print(pdswe.r)
# Out:
# 55.68176020408165
# 0.3
