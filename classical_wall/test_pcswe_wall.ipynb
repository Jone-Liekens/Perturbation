# %%
# %load_ext autoreload
# %reload_ext autoreload
# %autoreload 2

import numpy as np
from numpy import sin, cos, tan, atan, cosh, sinh, tanh, abs, linspace, min, max, argmin, argmax, pi, mean, exp, sqrt, zeros, ones, nan
import scipy
import matplotlib.pyplot as plt

from pcswe_wall import PCSWE_wall

# %%
pcswe = PCSWE_wall()
pcswe.H = 7.12
pcswe.A = 0.72
pcswe.L = 8e3

pcswe.r = 0.45
pcswe.h0 = 0.1

pcswe.tol = 1e-5

pcswe.set_derivative_vars()

pcswe.solve_LO()
pcswe.visualize_sol_LO()
# Out:
#    Iteration    Max residual  Max BC residual  Total nodes    Nodes added
#        1          9.10e-08       1.52e-09         1000             0
# Solved in 1 iterations, number of nodes 1000.
# Maximum relative residual: 9.10e-08
# Maximum boundary residual: 1.52e-09

# %%
pcswe.solve()
pcswe.visualize_sol()

pcswe.solve_h()
pcswe.visualize_sol_h()
# Out:
#    Iteration    Max residual  Max BC residual  Total nodes    Nodes added
#        1          5.49e-08       8.76e-19         2000             0
# Solved in 1 iterations, number of nodes 2000.
# Maximum relative residual: 5.49e-08
# Maximum boundary residual: 8.76e-19
#    Iteration    Max residual  Max BC residual  Total nodes    Nodes added
#        1          4.32e-07       4.64e-18         1000             0
# Solved in 1 iterations, number of nodes 1000.
# Maximum relative residual: 4.32e-07
# Maximum boundary residual: 4.64e-18
