# %%
# %load_ext autoreload
# %reload_ext autoreload
# %autoreload 2

import numpy as np
from numpy import sin, cos, tan, atan, cosh, sinh, tanh, abs, linspace, min, max, argmin, argmax, pi, mean, exp, sqrt, zeros, ones, nan
import scipy
import matplotlib.pyplot as plt

from pcswe_wall import PCSWE_wall
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
pcswe = PCSWE_wall()
pcswe.H = 7.12
pcswe.A = 0.72
pcswe.L = 8e3

pcswe.r = 0.45
pcswe.h0 = 0.1

pcswe.tol = 1e-5

pcswe.lmbda = 1e-8

pcswe.set_derivative_vars()

# pcswe.solve_LO()
# pcswe.visualize_sol_LO()


pcswe.use_alpha = True
pcswe.solve_h()
pcswe.visualize_sol_h()
# Out:
#    Iteration    Max residual  Max BC residual  Total nodes    Nodes added
#        1          3.04e-03       8.86e-19         1000           1084
#        2          1.26e-06       1.38e-23         2084             0
# Solved in 2 iterations, number of nodes 2084.
# Maximum relative residual: 1.26e-06
# Maximum boundary residual: 1.38e-23

# %%
pcswe.solve()
pcswe.visualize_sol()

# pcswe.lmbda = 1e-8

# pcswe.solve_h()
# pcswe.visualize_sol_h()
# Out:
#    Iteration    Max residual  Max BC residual  Total nodes    Nodes added
#        1          5.49e-08       8.76e-19         2000             0
# Solved in 1 iterations, number of nodes 2000.
# Maximum relative residual: 5.49e-08
# Maximum boundary residual: 8.76e-19

# %%
# pcswe.visualize_transport()
pcswe.transport_alpha()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 2
#       1 # pcswe.visualize_transport()
# ----> 2 pcswe.transport_alpha()
#
# File c:\Users\jolieken\Code\Perturbation\classical_wall\pcswe_wall.py:28, in transport_alpha(self)
#      26 self.lmbda = 6.8e-6
#      27 self.d50 = 0.13e-3
# ---> 28 self.phi = pi / 6 # 30 degrees
#      30 # universal constants
#      31 self.g = 9.81
#
# TypeError: unsupported operand type(s) for *: 'function' and 'float'

# %%
print(pcswe.y)
# Out:
#        message: The algorithm converged to the desired accuracy.
#        success: True
#         status: 0
#              x: [ 0.000e+00  5.003e-04 ...  9.995e-01  1.000e+00]
#            sol: <scipy.interpolate._interpolate.PPoly object at 0x00000299E383D950>
#              p: None
#              y: [[ 1.000e+00  1.000e+00 ...  1.015e+00  1.015e+00]
#                  [ 0.000e+00  3.752e-06 ...  1.130e-02  1.130e-02]
#                  ...
#                  [-2.087e-02 -2.088e-02 ... -8.511e-04  0.000e+00]
#                  [ 5.341e-01  5.343e-01 ...  2.590e-02  0.000e+00]]
#             yp: [[ 1.807e-02  1.807e-02 ...  8.851e-05 -0.000e+00]
#                  [ 7.500e-03  7.503e-03 ...  2.048e-04  0.000e+00]
#                  ...
#                  [-2.490e-02 -2.491e-02 ...  1.689e+00  1.714e+00]
#                  [ 4.435e-01  4.439e-01 ... -5.131e+01 -5.224e+01]]
#  rms_residuals: [ 4.970e-10  2.326e-10 ...  5.421e-08  5.485e-08]
#          niter: 1
