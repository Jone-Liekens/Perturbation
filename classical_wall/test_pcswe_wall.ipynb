# %%
# %load_ext autoreload
# %reload_ext autoreload
# %autoreload 2

import numpy as np
from numpy import sin, cos, tan, atan, cosh, sinh, tanh, abs, linspace, min, max, argmin, argmax, pi, mean, exp, sqrt, zeros, ones, nan
import scipy
import matplotlib.pyplot as plt

from pcswe_wall import PCSWE_wall
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
pcswe = PCSWE_wall()
pcswe.H = 7.12
pcswe.A = 0.72
pcswe.L = 8e3

pcswe.r = 0.45
pcswe.h0 = 0.1

pcswe.tol = 1e-5

pcswe.lmbda = 1e-8

pcswe.set_derivative_vars()

# pcswe.solve_LO()
# pcswe.visualize_sol_LO()


pcswe.use_alpha = True
pcswe.solve_h()
pcswe.visualize_sol_h()

# %%
pcswe.solve()
pcswe.visualize_sol()

# pcswe.lmbda = 1e-8

# pcswe.solve_h()
# pcswe.visualize_sol_h()
# Out:
#    Iteration    Max residual  Max BC residual  Total nodes    Nodes added
#        1          5.49e-08       8.76e-19         2000             0
# Solved in 1 iterations, number of nodes 2000.
# Maximum relative residual: 5.49e-08
# Maximum boundary residual: 8.76e-19

# %%
# pcswe.visualize_transport()
pcswe.transport_alpha()
# Out:
# (2000,)
# (1000,)
# (2000, 1000)
# (2000, 1000)
# [array([[0.00000000e+00, 3.01788706e-03],
#        [5.00250125e-04, 3.01928892e-03],
#        [1.00050025e-03, 3.02069067e-03],
#        ...,
#        [8.91445723e-01, 4.97349660e-05],
#        [8.91945973e-01, 1.88290994e-05],
#        [8.92248371e-01, 0.00000000e+00]], shape=(1785, 2)), array([[8.92248371e-01, 6.28318531e+00],
#        [8.92446223e-01, 6.28317293e+00],
#        [8.92946473e-01, 6.28314143e+00],
#        ...,
#        [1.00050025e-03, 3.14827380e+00],
#        [5.00250125e-04, 3.14827057e+00],
#        [0.00000000e+00, 3.14826735e+00]], shape=(2713, 2))]
# (1785, 2)
# (2713, 2)
# (3998,) (3998,)
# [   0    0    1 ... 1997 1998 1998]
