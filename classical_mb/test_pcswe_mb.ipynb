# %%
# %load_ext autoreload
# %reload_ext autoreload
# %autoreload 2

import numpy as np
from numpy import sin, cos, tan, atan, cosh, sinh, tanh, abs, linspace, min, max, argmin, argmax, pi, mean, exp, sqrt, zeros, ones, nan
import scipy
import matplotlib.pyplot as plt

from pcswe_mb import PCSWE_mb
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
pcswe = PCSWE_mb()
pcswe.h0 = 0.1
pcswe.r = 0.45

pcswe.bnd_FO_hop = 1e-14
pcswe.bnd_LO_hop = 1e-11
pcswe.set_derivative_vars()

# res, sol = pcswe.solve_shooting()
# pcswe.visualize_sol(0)
# pcswe.visualize_sol(0.9)

# %%
# pcswe.solve_bvp()

# # pcswe.visualize_sol(0)
# pcswe.visualize_sol(0.995)

# %%
pcswe.solve_h()
pcswe.visualize_sol_h()
# Out:
#    Iteration    Max residual  Max BC residual  Total nodes    Nodes added
#        1          2.52e-06       1.21e-17         1000             0
# Solved in 1 iterations, number of nodes 1000.
# Maximum relative residual: 2.52e-06
# Maximum boundary residual: 1.21e-17
