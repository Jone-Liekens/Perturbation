# %%
# %load_ext autoreload
# %reload_ext autoreload
# %autoreload 2

import numpy as np
import matplotlib.pyplot as plt

# %%
from pcswe import PerturbationCSWE

# %%
tau = 0

h_fx = lambda x: ((1+tau) * x + (-tau) * x**2)
h_fx_dx = lambda x: (1 + tau + 2*(-tau)*x)
h_fx_dxx = lambda x: 0


h_fx = lambda x: x
h_fx_dx = lambda x: 1
h_fx_dxx = lambda x: 0


pcswe = PerturbationCSWE()
pcswe.H = 7.12
pcswe.A = 0.72
pcswe.L = 8e3
pcswe.r = 0
pcswe.h0 = 0.1

pcswe.h_fx = h_fx
pcswe.h_fx_dx = h_fx_dx
pcswe.h_fx_dxx = h_fx_dxx

pcswe.tol = 1e-4
pcswe.small_number = 1e-4

pcswe.set_derivative_vars()



# pcswe.solve()
# pcswe.visualize_components()

pcswe.solve()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 30
#      25 pcswe.small_number = 1e-4
#      27 pcswe.set_derivative_vars()
# ---> 30 pcswe.solve_LO()
#      33 # pcswe.solve()
#      34 # pcswe.visualize_components()
#      36 pcswe.solve()
#
# File c:\Users\jolieken\Code\Perturbation\pcswe.py:387, in PerturbationCSWE.solve_LO(self)
#     384 y_guess = 0.1 * np.ones((4, len(self.x)))
#     386 # sol = scipy.integrate.solve_bvp(self.deriv_LO, self.bc_moving_boundary_LO, self.x, y_guess, tol=self.tol, max_nodes=20000, verbose=2)
# --> 387 sol = solve_bvp_s45(self.deriv_LO, self.bc_moving_boundary_LO, self.x, y_guess, s=3, tol=self.tol, max_nodes=20000, verbose=2)
#     388 # sol = solve_bvp_s2(self.deriv_LO, self.bc_moving_boundary_LO, self.x, y_guess, tol=self.tol, max_nodes=20000, verbose=2)
#     389 # sol = solve_bvp_orig(self.deriv_LO, self.bc_moving_boundary_LO, self.x, y_guess, tol=self.tol, max_nodes=20000, verbose=2)
#     390 try:
#
# NameError: name 'solve_bvp_s45' is not defined

# %%
pcswe.visualize_components()

# %%
pcswe.visualize_transport()
