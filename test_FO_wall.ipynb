# %%
# %load_ext autoreload
# %reload_ext autoreload
# %autoreload 2

import numpy as np
import matplotlib.pyplot as plt

from matplotlib import cm
from numpy.polynomial import chebyshev
from cycler import cycler
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from pcswe import PerturbationCSWE

# %%
tau = 0.1

h_fx = lambda x: 0.9*((1+tau) * x + (-tau) * x**2)
h_fx_dx = lambda x: 0.9*(1 + tau + 2*(-tau)*x)
h_fx_dxx = lambda x: 0


pcswe = PerturbationCSWE()
pcswe.H = 7.12
pcswe.A = 0.72
pcswe.L = 8e3
pcswe.r = 0.3
pcswe.h0 = 0.2

pcswe.h_fx = h_fx
pcswe.h_fx_dx = h_fx_dx
pcswe.h_fx_dxx = h_fx_dxx

pcswe.tol = 1e-6
pcswe.small_number = 1e-7

pcswe.bc = pcswe.bc_wall

pcswe.set_derivative_vars()

# pcswe.solve()
# pcswe.visualize_components()

pcswe.solve()
pcswe.visualize_components()

pcswe.visualize_transport()
# Out:
# 0.0001590119038510525
# 1.8635996805140166e-05
# 5.9616285383371886e-15
# 84761.90476190478

# %%
n_colors = 40
colors = plt.cm.viridis(np.linspace(0, 1, n_colors-1))
custom_cycler = (cycler(color=colors[::-1]))
plt.rcParams['axes.prop_cycle'] = custom_cycler


# pcswe.lmbda = 0

timestep = 2e-2

fig, axs = plt.subplots(2, 3, figsize=(30, 20))
for i in range(40):
    pcswe.transport_step(timestep)
    if i % 2 == 0:
        # pcswe.visualize_components()
        # pcswe.visualize_transport()

        x, u5_xt, q_xt, q_x, q_x_trap, q_x_dx, q_x_dx_num, b_x, b_x_dx, h_x_dt = pcswe.transport()

        
        axs[0, 0].plot(x, pcswe.h_fx(x))#, 'brown', linewidth=4)
        # axs[0, 1].plot(x, q_x_trap, 'o')
        # axs[0, 1].plot(x, q_x_gl, 'x', ms=5)
        axs[0, 1].plot(x, q_x)#, 'k')
        axs[0, 2].plot(x, b_x)

        axs[1, 0].plot(x, h_x_dt)#, color='brown', linestyle='-')
        axs[1, 1].plot(x, q_x_dx)
        axs[1, 2].plot(x, b_x_dx)

plt.show()
# Out:
# 0.0001590119038510525
# 1.8635996805140166e-05
# 5.9616285383371886e-15
# 84761.90476190478
# 5.217998282955356e-12
# 0.0001590119038510525
# 1.8635996805140166e-05
# 5.9616285383371886e-15
# 84761.90476190478
# 0.0001590119038510525
# 1.8635996805140166e-05
# 5.9616285383371886e-15
# 84761.90476190478
# 3.049880354820625e-09
# 0.0001590119038510525
# 1.8635996805140166e-05
# 5.9616285383371886e-15
# 84761.90476190478
# 3.5969048647958873e-09
# 0.0001590119038510525
# 1.8635996805140166e-05
# 5.9616285383371886e-15
# 84761.90476190478
# 0.0001590119038510525
# 1.8635996805140166e-05
# 5.9616285383371886e-15
# 84761.90476190478
# 4.081444814534503e-09
# 0.0001590119038510525
# 1.8635996805140166e-05
# 5.9616285383371886e-15
# 84761.90476190478
# 4.544461750822042e-09
# 0.0001590119038510525
# 1.8635996805140166e-05
# 5.9616285383371886e-15
# 84761.90476190478
# 0.0001590119038510525
# 1.8635996805140166e-05
# 5.9616285383371886e-15
# 84761.90476190478
# 4.996375774056777e-09
# ...

# %%
pcswe.visualize_transport()
# Out:
# 0.0001590119038510525
# 1.8635996805140166e-05
# 5.9616285383371886e-15
# 84761.90476190478

# %%
plt.rcdefaults()
for tau in [0.5, 0, -0.5, -1]:
    h_fx = lambda x: 0.9*((1+tau) * x + (-tau) * x**2)
    h_fx_dx = lambda x: 0.9*(1 + tau + 2*(-tau)*x)
    h_fx_dxx = lambda x: 0


    pcswe = PerturbationCSWE()
    pcswe.H = 7.12
    pcswe.A = 0.72
    pcswe.L = 8e3
    pcswe.r = 0
    pcswe.h0 = 0.1

    pcswe.h_fx = h_fx
    pcswe.h_fx_dx = h_fx_dx
    pcswe.h_fx_dxx = h_fx_dxx

    pcswe.tol = 1e-6
    pcswe.small_number = 1e-7

    pcswe.bc = pcswe.bc_wall

    pcswe.set_derivative_vars()

    # pcswe.solve()
    # pcswe.visualize_components()

    pcswe.solve()
    pcswe.visualize_transport()
# Out:
# 0.0001590119038510525
# 1.8635996805140166e-05
# 5.9616285383371886e-15
# 84761.90476190478
# 0.0001590119038510525
# 1.8635996805140166e-05
# 5.9616285383371886e-15
# 84761.90476190478
# 0.0001590119038510525
# 1.8635996805140166e-05
# 5.9616285383371886e-15
# 84761.90476190478
# 0.0001590119038510525
# 1.8635996805140166e-05
# 5.9616285383371886e-15
# 84761.90476190478
