# %%
# %load_ext autoreload
# %reload_ext autoreload
# %autoreload 2

# %%
import numpy as np
import scipy
from pcswe import *

# %%
pcswe = PerturbationCSWE()
pcswe.H = 7.12
pcswe.A = 0.72
pcswe.L = 8e3

pcswe.r = 0.45
pcswe.h0 = 0.1

pcswe.tol = 1e-8
pcswe.small_number = 0

pcswe.set_derivative_vars()

# pcswe.solve()
# pcswe.visualize_components()

pcswe.solve_LO()
# pcswe.product_dxx(pcswe.y0.x, pcswe.y0.y, pcswe.deriv_LO(pcswe.y0.x, pcswe.y0.y))
pcswe.visualize_LO()
# Out:
#    Iteration    Max residual  Max BC residual  Total nodes    Nodes added
#        1          2.43e-05       0.00e+00         2000             7
#        2          8.15e-06       0.00e+00         2007             6
#        3          2.72e-06       0.00e+00         2013             4
#        4          9.07e-07       0.00e+00         2017             4
#        5          3.02e-07       0.00e+00         2021             3
#        6          1.01e-07       0.00e+00         2024             3
#        7          3.36e-08       0.00e+00         2027             1
#        8          1.68e-08       0.00e+00         2028             1
#        9          8.48e-09       0.00e+00         2029             2
#       10          1.01e-08       2.22e-16         2031             3
#       11          1.25e-08       2.22e-16         2034             6
#       12          1.38e-08       2.22e-16         2040            12
#       13          2.50e-08       2.22e-16         2052            24
#       14          5.08e-08       3.47e-18         2076            48
#       15          1.32e-07       3.47e-18         2124            99
#       16          2.89e-07       3.47e-18         2223            300
#       17          8.00e-07       0.00e+00         2523            918
#       18          2.77e-06       0.00e+00         3441           2826
#       19          7.13e-06       0.00e+00         6267           8478
#       20          4.34e-05       0.00e+00         14745         (25434)
# Number of nodes is exceeded after iteration 20.
# Maximum relative residual: 4.34e-05
# Maximum boundary residual: 0.00e+00
#        message: The maximum number of mesh nodes is exceeded.
#        success: False
#         status: 1
#              x: [ 0.000e+00  5.003e-04 ...  1.000e+00  1.000e+00]
#            sol: <scipy.interpolate._interpolate.PPoly object at 0x000001321A728590>
#              p: None
#              y: [[ 1.000e+00  1.000e+00 ...  1.018e+00  1.018e+00]
#                  [ 0.000e+00  3.766e-06 ...  1.987e-02  1.987e-02]
#                  [ 6.305e-03  6.308e-03 ...  1.987e-02  1.987e-02]
#                  [-1.009e+00 -1.009e+00 ... -1.018e+00 -1.018e+00]]
#             yp: [[ 1.807e-02  1.807e-02 ...  1.668e-02  1.668e-02]
#                  [ 7.526e-03  7.530e-03 ...  8.262e-02  8.262e-02]
#                  [ 6.305e-03  6.308e-03 ...  4.131e-02  4.131e-02]
#                  [-9.024e-03 -9.024e-03 ... -8.347e-03 -8.338e-03]]
#  rms_residuals: [ 1.527e-13  3.386e-13 ...  1.695e-05  8.067e-06]
#          niter: 20
# ---------------------------------------------------------------------------
# SystemError                               Traceback (most recent call last)
# Cell In[5], line 17
#      12 pcswe.set_derivative_vars()
#      14 # pcswe.solve()
#      15 # pcswe.visualize_components()
# ---> 17 pcswe.solve_LO()
#      18 # pcswe.product_dxx(pcswe.y0.x, pcswe.y0.y, pcswe.deriv_LO(pcswe.y0.x, pcswe.y0.y))
#      19 pcswe.visualize_LO()
#
# File c:\Users\jolieken\Code\Perturbation\pcswe.py:306, in PerturbationCSWE.solve_LO(self)
#     304 if sol.status or self.debug:
#     305     print(sol)
# --> 306     raise SystemError
#     308 self.y0 = sol
#
# SystemError:
