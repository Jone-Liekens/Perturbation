# %%
from pytexit import py2tex
import re

# %%
pattern = r"(\w+)\(x\)"
    
    # The replacement string:
# 1. r"d\1(x)/dx" : The '\1' refers back to the content of the first capturing group (the function name).
# This constructs the string 'd' + function_name + '(x)/dx'.
replacement = r"d\1(x)/dx"

# Perform the substitution globally (all occurrences)
re.sub(pattern, replacement, text)

# %%
"""
self.kappa \kappa
self.r r

u1r_x_dx u^1_{r,x}
u1c_x_dx u^1_{c,x}
u1s_x_dx u^1_{s,x}
dz1r_x_dx \zeta^1_{r,x}
dz1c_x_dx \zeta^1_{c,x}
dz1s_x_dx \zeta^1_{s,x}

u0c_x_dx u^0_{c,x}
u0s_x_dx u^0_{s,x}
dz0c_x_dx \zeta^0_{c,x}
dz0s_x_dx \zeta^0_{s,x}

u1r_x u^1_r
u1c_x u^1_c
u1s_x u^1_s
dz1r_x \zeta^1_r
dz1c_x \zeta^1_c
dz1s_x \zeta^1_s

u0c_x u^0_c
u0s_x u^0_s
dz0c_x \zeta^0_c
dz0s_x \zeta^0_s

"""
